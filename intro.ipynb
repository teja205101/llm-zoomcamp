# %%
1+2
# Out:
# 3

# %%
from openai import OpenAI

# %%
client = OpenAI(api_key="YOUR_API_KEY_HERE")

# %%
import os

# %%
os.environ
# Out:
# environ{'TERM_PROGRAM': 'vscode',
#         'TERM': 'xterm-color',
#         'SHELL': '/bin/bash',
#         'TMPDIR': '/var/folders/jz/rq4n1td114xbky20c80bzdk00000gn/T/',
#         'VSCODE_PYTHON_AUTOACTIVATE_GUARD': '1',
#         'TERM_PROGRAM_VERSION': '1.107.0',
#         'MallocNanoZone': '0',
#         'USER': 'tejamadu',
#         'COMMAND_MODE': 'unix2003',
#         'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.JHZpZdMBAV/Listeners',
#         '__CF_USER_TEXT_ENCODING': '0x1F5:0:0',
#         'PATH': '/usr/local/bin:/System/Cryptexes/App/usr/bin:/usr/bin:/bin:/usr/sbin:/sbin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/local/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/bin:/var/run/com.apple.security.cryptexd/codex.system/bootstrap/usr/appleinternal/bin:/opt/pmk/env/global/bin:/Library/Apple/usr/bin:/usr/local/share/dotnet:~/.dotnet/tools:/usr/local/go/bin:/Library/Frameworks/Mono.framework/Versions/Current/Commands',
# ...

# %%
response = client.chat.completions.create(
    model ="gpt-4o",
    messages=[{"role":"user","content":"is it too hot in Austin Today"}]
)

# %%
response.choices[0].message.content
# Out:
# "I'm sorry, but I don't have real-time data access to provide current weather information. To find out the current temperature in Austin, you might want to check a reliable weather website or use a weather app."
